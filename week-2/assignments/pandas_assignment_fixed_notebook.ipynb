# %% [markdown]
# <a href="https://colab.research.google.com/github/byrocuy/REA-AI_Mastery/blob/main/week-2/assignments/pandas_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment: FIFA 21 Players Data Analysis and Visualization

# %% [markdown]
# **Instructions for Students:**
#
# Please carefully follow these steps to complete and submit your assignment:
#
# 1. **Completing the Assignment**: You are required to work on and complete all tasks in the provided assignment. Be disciplined and ensure that you thoroughly engage with each task.
#
# 2. **Creating a Google Drive Folder**: Each of you must create a new folder on your Google Drive. This will be the repository for all your completed assignment files, aiding you in keeping your work organized and accessible.
#
# 3. **Uploading Completed Assignment**: Upon completion of your assignment, make sure to upload all necessary files, involving codes, reports, and related documents into the created Google Drive folder. Save this link in the 'Student Identity' section and also provide it as the last parameter in the `submit` function that has been provided.
#
# 4. **Sharing Folder Link**: You're required to share the link to your assignment Google Drive folder. This is crucial for the submission and evaluation of your assignment.
#
# 5. **Setting Permission toPublic**: Please make sure your Google Drive folder is set to public. This allows your instructor to access your solutions and assess your work correctly.
#
# Adhering to these procedures will facilitate a smooth assignment process for you and the reviewers.

# %% [markdown]
# **Description:**
#
# Welcome to this data analysis and visualization assignment! In this assignment, we will be exploring the 'FIFA 21 Players' dataset which comprises a rich variety of information about soccer players from around the world. The data extracted are in 'csv' file format.
#
# Your task is to clean and prepare the data for analysis, and then leverage your data visualization skills to uncovers insights about FIFA 21 players, teams, and overall value and wage dynamics.
#
# Here are your tasks outlined in detail:
#
# 1. **Data Cleaning**: The initial dataset contains some unnecessary and redundant information. Your first task is to clean and prepare it for analysis. In doing so:
#     - Remove the 'Unnamed: 0' column from the dataset.
#     - Removing the Newline Characters.
#     - Look for columns which contain star ('★') characters. Remove these characters from all such columns.
#     - Fill in the missing values using an appropriate method.
#     - In the 'Value', 'Wage', and 'Release Clause' columns, remove the '€', 'K', and 'M' characters and convert the currency value to 'int'. For eg, "M" in value column is Million, so multiply the row values by 1,000,000, etc.
#
# 2. **Data Visualization**: After the data has been cleaned and prepared, use appropriate data visualization methods to represent the data as follows:
#     - Create a Pie Chart to display the preferred foot ('Left' or 'Right') among the FIFA 21 players.
#     - Use a Bar Plot to represent the top 3 FIFA 21 players.
#     - Visualize the best FIFA teams from 100 players based on the 'OVA' score using a Bar Plot.
#     - Use a Bar Plot to display the top 10 most valuable FIFA teams.
#     - Create a Scatter Plot to show players who are highly valuable but still underpaid.
#
# Ensure all plots are fully labeled with titles, x and y variables, and a legend if necessary.
#
# Remember, the goal of this assignment is not just about getting the right answer but also about presenting your findings in a clear, logical, and visually appealing manner. Good luck and enjoy the analysis!

# %% [markdown]
# **Note for Students:**
#
# Please bear in mind that, although you may tackle most of the assignment problems in any order you prefer, **tasks 9 and 10 require that you complete task 5 first**. This is due to the dependencies these tasks have on the cleaned and prepared financial data ('Value' and 'Wage' columns) from task 5.
#
# **You will not be able to accurately complete tasks 9 and 10 without having concluded task 5**. Conversely, other tasks in this assignment do not have such interdependencies and can be completed independently.
#
# Happy analyzing!

# %% [markdown]
# ## Student Identity

# %%
# @title #### Student Identity
student_id = "REA3X33Z" # @param {type:"string"}
name = "Roby Attoillah" # @param {type:"string"}
drive_link = "https://drive.google.com/drive/folders/151ZVu1hFXhyW9IEQXdT1lRaoAKYmaR0R?usp=sharing"  # @param {type:"string"}

# %% [markdown]
# ## Import package

# %%
# !pip install -U matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\byrocuy\appdata\local\programs\python\python38\lib\site-packages (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\byrocuy\appdata\local\programs\python\python38\lib\site-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\byrocuy\appdata\local\programs\python\python38\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\byrocuy\appdata\local\programs\python\python38\lib\site-packages (from matplotlib) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\byrocuy\appdata\local\programs\python\python38\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in c:\users\byrocuy\appdata\local\programs\python\python38\lib\site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\byrocuy\appdata\local\programs\python\python38\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\byrocuy\appdata\local\programs\python\python38\lib\site-packages (from matplotlib) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\byrocuy\appdata\local\programs\python\python38\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\byrocuy\appdata\local\programs\python\python38\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\byrocuy\appdata\local\programs\python\python38\lib\site-packages (from matplotlib) (6.0.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\byrocuy\appdata\local\programs\python\python38\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.16.2)
# Requirement already satisfied: six>=1.5 in c:\users\byrocuy\appdata\local\programs\python\python38\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# !pip install -U rggrader -q
from rggrader import submit
from rggrader import submit_image

# %% [markdown]
# ## Read file

# %%
url = 'https://storage.googleapis.com/rg-ai-bootcamp/assignment-1/fifa21_raw_data.csv'
fifa_df = pd.read_csv(url, low_memory=False)
fifa_df
# Out:
#        Unnamed: 0      ID               Name                      LongName  \
# 0               0  158023           L. Messi                  Lionel Messi
# 1               1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2               2  200389           J. Oblak                     Jan Oblak
# 3               3  192985       K. De Bruyne               Kevin De Bruyne
# 4               4  190871          Neymar Jr    Neymar da Silva Santos Jr.
# ...           ...     ...                ...                           ...
# 18974       18974  247223             Xia Ao                        Ao Xia
# 18975       18975  258760           B. Hough                     Ben Hough
# 18976       18976  252757        R. McKinley                Ronan McKinley
# 18977       18977  243790       Wang Zhen'ao                  Zhen'ao Wang
# 18978       18978  252520          Zhou Xiao                     Xiao Zhou
#
#       Nationality  Age  ↓OVA  POT                         Club     Contract  \
# 0       Argentina   33    93   93         \n\n\n\nFC Barcelona  2004 ~ 2021
# 1        Portugal   35    92   92             \n\n\n\nJuventus  2018 ~ 2022
# 2        Slovenia   27    91   93      \n\n\n\nAtlético Madrid  2014 ~ 2023
# 3         Belgium   29    91   91      \n\n\n\nManchester City  2015 ~ 2023
# 4          Brazil   28    91   91  \n\n\n\nParis Saint-Germain  2017 ~ 2022
# ...           ...  ...   ...  ...                          ...          ...
# 18974    China PR   21    47   55           \n\n\n\nWuhan Zall  2018 ~ 2022
# 18975     England   17    47   67      \n\n\n\nOldham Athletic  2020 ~ 2021
# 18976     England   18    47   65           \n\n\n\nDerry City  2019 ~ 2020
# 18977    China PR   20    47   57     \n\n\n\nDalian YiFang FC  2020 ~ 2022
# 18978    China PR   21    47   57     \n\n\n\nDalian YiFang FC  2019 ~ 2023
#
#        ...     A/W     D/W   IR PAC  SHO PAS DRI DEF PHY Hits
# 0      ...  Medium     Low  5 ★  85   92  91  95  38  65  771
# 1      ...    High     Low  5 ★  89   93  81  89  35  77  562
# 2      ...  Medium  Medium  3 ★  87   92  78  90  52  90  150
# 3      ...    High    High  4 ★  76   86  93  88  64  78  207
# 4      ...    High  Medium  5 ★  91   85  86  94  36  59  595
# ...    ...     ...     ...  ...  ..  ...  ..  ..  ..  ..  ...
# 18974  ...  Medium  Medium  1 ★  64   28  26  38  48  51  NaN
# 18975  ...  Medium  Medium  1 ★  64   40  48  49  35  45  NaN
# 18976  ...  Medium  Medium  1 ★  63   39  44  46  40  53  NaN
# 18977  ...  Medium  Medium  1 ★  58   49  41  49  30  44  NaN
# 18978  ...  Medium  Medium  1 ★  62   22  39  42  45  55  NaN
#
# [18979 rows x 35 columns]

# %%
fifa_df['Club'].value_counts()
# Out:
# Club
# No Club                           237
# \n\n\n\nFC Barcelona               33
# \n\n\n\nBurnley                    33
# \n\n\n\nRC Celta                   33
# \n\n\n\nTorino                     33
#                                  ...
# \n\n\n\nMelbourne Victory          18
# \n\n\n\nBrisbane Roar              18
# \n\n\n\nAdelaide United            18
# \n\n\n\nPerth Glory                18
# \n\n\n\nCentral Coast Mariners     18
# Name: count, Length: 682, dtype: int64

# %%
fifa_df.describe()
# Out:
#          Unnamed: 0             ID           Age          ↓OVA           POT  \
# count  18979.000000   18979.000000  18979.000000  18979.000000  18979.000000
# mean    9489.000000  226403.384794     25.194109     65.718636     71.136414
# std     5478.909715   27141.054157      4.710520      6.968999      6.114635
# min        0.000000      41.000000     16.000000     47.000000     47.000000
# 25%     4744.500000  210135.000000     21.000000     61.000000     67.000000
# 50%     9489.000000  232418.000000     25.000000     66.000000     71.000000
# 75%    14233.500000  246922.500000     29.000000     70.000000     75.000000
# max    18978.000000  259216.000000     53.000000     93.000000     95.000000
#
#                 BOV   Total Stats    Base Stats           PAC           SHO  \
# count  18979.000000  18979.000000  18979.000000  18979.000000  18979.000000
# mean      66.751726   1595.286949    355.702197     67.453975     53.457031
# std        6.747193    269.874789     40.761117     10.677859     13.827425
# min       48.000000    747.000000    232.000000     25.000000     16.000000
# 25%       62.000000   1452.000000    327.000000     61.000000     44.000000
# 50%       67.000000   1627.000000    356.000000     68.000000     56.000000
# 75%       71.000000   1781.000000    384.000000     75.000000     64.000000
# max       93.000000   2316.000000    498.000000     96.000000     93.000000
#
#                 PAS           DRI           DEF           PHY
# count  18979.000000  18979.000000  18979.000000  18979.000000
# mean      57.681016     62.875020     49.866221     64.368934
# std       10.081857      9.927415     16.443213      9.601883
# min       25.000000     25.000000     12.000000     28.000000
# 25%       51.000000     57.000000     35.000000     58.000000
# 50%       58.000000     64.000000     53.000000     65.000000
# 75%       64.000000     69.000000     63.000000     71.000000
# max       93.000000     95.000000     91.000000     91.000000

# %%
fifa_df.describe(include=[object])
# Out:
#                 Name    LongName Nationality     Club     Contract Positions  \
# count          18979       18979       18979    18979        18979     18979
# unique         17920       18852         164      682          131       640
# top     J. Rodríguez  Danny Rose     England  No Club  2019 ~ 2021        CB
# freq              13           3        1705      237         1706      2441
#
#        Height Weight Preferred Foot Best Position  ... Loan Date End  Value  \
# count   18979  18979          18979         18979  ...          1013  18979
# unique     62     79              2            15  ...            24    255
# top     180cm   70kg          Right            CB  ...  Jun 30, 2021  €1.2M
# freq     1474   1495          14445          3686  ...           770    582
#
#          Wage Release Clause    W/F     SM     A/W     D/W     IR   Hits
# count   18979          18979  18979  18979   18979   18979  18979  16384
# unique    134           1216      5      5       3       3      5    439
# top       €2K             €0    3 ★     2★  Medium  Medium    1 ★      1
# freq     2899           1261  11695   9142   12701   13956  17629   2337
#
# [4 rows x 21 columns]

# %%
fifa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18979 entries, 0 to 18978
# Data columns (total 35 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      18979 non-null  int64
#  1   ID              18979 non-null  int64
#  2   Name            18979 non-null  object
#  3   LongName        18979 non-null  object
#  4   Nationality     18979 non-null  object
#  5   Age             18979 non-null  int64
#  6   ↓OVA            18979 non-null  int64
#  7   POT             18979 non-null  int64
#  8   Club            18979 non-null  object
#  9   Contract        18979 non-null  object
#  10  Positions       18979 non-null  object
#  11  Height          18979 non-null  object
#  12  Weight          18979 non-null  object
#  13  Preferred Foot  18979 non-null  object
#  14  BOV             18979 non-null  int64
#  15  Best Position   18979 non-null  object
#  16  Joined          18979 non-null  object
#  17  Loan Date End   1013 non-null   object
#  18  Value           18979 non-null  object
#  19  Wage            18979 non-null  object
#  20  Release Clause  18979 non-null  object
#  21  Total Stats     18979 non-null  int64
#  22  Base Stats      18979 non-null  int64
#  23  W/F             18979 non-null  object
#  24  SM              18979 non-null  object
#  25  A/W             18979 non-null  object
#  26  D/W             18979 non-null  object
#  27  IR              18979 non-null  object
#  28  PAC             18979 non-null  int64
#  29  SHO             18979 non-null  int64
#  30  PAS             18979 non-null  int64
#  31  DRI             18979 non-null  int64
#  32  DEF             18979 non-null  int64
#  33  PHY             18979 non-null  int64
#  34  Hits            16384 non-null  object
# dtypes: int64(14), object(21)
# memory usage: 5.1+ MB

# %%
fifa_df.isnull().sum().sort_values(ascending=False).head()
# Out:
# Loan Date End    17966
# Hits              2595
# Name                 0
# Wage                 0
# PHY                  0
# dtype: int64

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# **Task 1: Removing the 'Unnamed: 0' Column**
#
# In this first task, you have to deal with unnecessary data in our data set. Specifically, the data set contains a column labeled `Unnamed: 0`, which does not make a significant contribution to our data analysis needs. Your goal is to effectively remove this column from the `FIFA 21 Players` data set. Remember that it is very important to manipulate only the unneeded parts of the data and keep the rest intact.
#
# Please make sure to:
# - Read the CSV file carefully to understand the structure of the data.
# - Identify a suitable method to remove the specified column from the DataFrame.
# - Validate that the column has been removed successfully by inspecting the resulting DataFrame.

# %%
fifa_df.drop(['Unnamed: 0'], axis=1)
# Out:
#            ID               Name                      LongName Nationality  \
# 0      158023           L. Messi                  Lionel Messi   Argentina
# 1       20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro    Portugal
# 2      200389           J. Oblak                     Jan Oblak    Slovenia
# 3      192985       K. De Bruyne               Kevin De Bruyne     Belgium
# 4      190871          Neymar Jr    Neymar da Silva Santos Jr.      Brazil
# ...       ...                ...                           ...         ...
# 18974  247223             Xia Ao                        Ao Xia    China PR
# 18975  258760           B. Hough                     Ben Hough     England
# 18976  252757        R. McKinley                Ronan McKinley     England
# 18977  243790       Wang Zhen'ao                  Zhen'ao Wang    China PR
# 18978  252520          Zhou Xiao                     Xiao Zhou    China PR
#
#        Age  ↓OVA  POT                         Club     Contract   Positions  \
# 0       33    93   93         \n\n\n\nFC Barcelona  2004 ~ 2021  RW, ST, CF
# 1       35    92   92             \n\n\n\nJuventus  2018 ~ 2022      ST, LW
# 2       27    91   93      \n\n\n\nAtlético Madrid  2014 ~ 2023          GK
# 3       29    91   91      \n\n\n\nManchester City  2015 ~ 2023     CAM, CM
# 4       28    91   91  \n\n\n\nParis Saint-Germain  2017 ~ 2022     LW, CAM
# ...    ...   ...  ...                          ...          ...         ...
# 18974   21    47   55           \n\n\n\nWuhan Zall  2018 ~ 2022          CB
# 18975   17    47   67      \n\n\n\nOldham Athletic  2020 ~ 2021          CM
# 18976   18    47   65           \n\n\n\nDerry City  2019 ~ 2020          CM
# 18977   20    47   57     \n\n\n\nDalian YiFang FC  2020 ~ 2022          RW
# 18978   21    47   57     \n\n\n\nDalian YiFang FC  2019 ~ 2023      CB, LB
#
#        ...     A/W     D/W   IR  PAC SHO PAS DRI DEF PHY Hits
# 0      ...  Medium     Low  5 ★   85  92  91  95  38  65  771
# 1      ...    High     Low  5 ★   89  93  81  89  35  77  562
# 2      ...  Medium  Medium  3 ★   87  92  78  90  52  90  150
# 3      ...    High    High  4 ★   76  86  93  88  64  78  207
# 4      ...    High  Medium  5 ★   91  85  86  94  36  59  595
# ...    ...     ...     ...  ...  ...  ..  ..  ..  ..  ..  ...
# 18974  ...  Medium  Medium  1 ★   64  28  26  38  48  51  NaN
# 18975  ...  Medium  Medium  1 ★   64  40  48  49  35  45  NaN
# 18976  ...  Medium  Medium  1 ★   63  39  44  46  40  53  NaN
# 18977  ...  Medium  Medium  1 ★   58  49  41  49  30  44  NaN
# 18978  ...  Medium  Medium  1 ★   62  22  39  42  45  55  NaN
#
# [18979 rows x 34 columns]

# %%
# @title #### 01. Removing the 'Unnamed: 0' Column

# Put your code here:
# fifa_df = fifa_df.drop(['Unnamed: 0'], axis=1)
display(fifa_df)

# ---- End of your code ----

# Submit Method
assignment_id = "00_fifa_21_players_data_analysis_and_visualization"
question_id = "01_removing_the_unnamed_column"
# submit(student_id, name, assignment_id, fifa_df.head(1).to_string(), question_id, drive_link)
# Out:
#        Unnamed: 0      ID               Name                      LongName  \
# 0               0  158023           L. Messi                  Lionel Messi
# 1               1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2               2  200389           J. Oblak                     Jan Oblak
# 3               3  192985       K. De Bruyne               Kevin De Bruyne
# 4               4  190871          Neymar Jr    Neymar da Silva Santos Jr.
# ...           ...     ...                ...                           ...
# 18974       18974  247223             Xia Ao                        Ao Xia
# 18975       18975  258760           B. Hough                     Ben Hough
# 18976       18976  252757        R. McKinley                Ronan McKinley
# 18977       18977  243790       Wang Zhen'ao                  Zhen'ao Wang
# 18978       18978  252520          Zhou Xiao                     Xiao Zhou
#
#       Nationality  Age  ↓OVA  POT                         Club     Contract  \
# 0       Argentina   33    93   93         \n\n\n\nFC Barcelona  2004 ~ 2021
# 1        Portugal   35    92   92             \n\n\n\nJuventus  2018 ~ 2022
# 2        Slovenia   27    91   93      \n\n\n\nAtlético Madrid  2014 ~ 2023
# 3         Belgium   29    91   91      \n\n\n\nManchester City  2015 ~ 2023
# 4          Brazil   28    91   91  \n\n\n\nParis Saint-Germain  2017 ~ 2022
# ...           ...  ...   ...  ...                          ...          ...
# 18974    China PR   21    47   55           \n\n\n\nWuhan Zall  2018 ~ 2022
# 18975     England   17    47   67      \n\n\n\nOldham Athletic  2020 ~ 2021
# 18976     England   18    47   65           \n\n\n\nDerry City  2019 ~ 2020
# 18977    China PR   20    47   57     \n\n\n\nDalian YiFang FC  2020 ~ 2022
# 18978    China PR   21    47   57     \n\n\n\nDalian YiFang FC  2019 ~ 2023
#
#        ...     A/W     D/W   IR PAC  SHO PAS DRI DEF PHY Hits
# 0      ...  Medium     Low  5 ★  85   92  91  95  38  65  771
# 1      ...    High     Low  5 ★  89   93  81  89  35  77  562
# 2      ...  Medium  Medium  3 ★  87   92  78  90  52  90  150
# 3      ...    High    High  4 ★  76   86  93  88  64  78  207
# 4      ...    High  Medium  5 ★  91   85  86  94  36  59  595
# ...    ...     ...     ...  ...  ..  ...  ..  ..  ..  ..  ...
# 18974  ...  Medium  Medium  1 ★  64   28  26  38  48  51  NaN
# 18975  ...  Medium  Medium  1 ★  64   40  48  49  35  45  NaN
# 18976  ...  Medium  Medium  1 ★  63   39  44  46  40  53  NaN
# 18977  ...  Medium  Medium  1 ★  58   49  41  49  30  44  NaN
# 18978  ...  Medium  Medium  1 ★  62   22  39  42  45  55  NaN
#
# [18979 rows x 35 columns]

# %% [markdown]
# **Task 2: Removing the Newline Characters**
#
# In your second task, you will navigate into deeper waters of data cleaning by removing the newline characters (`\n`) from the dataset. This nuisance feature could occur in various columns and can disrupt accurate data parsing. So, it's an important step to assure the integrity and consistency of our data.
#
# Here are a few tips to guide you on this task:
# - Start by detecting which columns in the 'FIFA 21 Players' dataset contain newline characters
# - Develop a strategy to effectively clean the data by replacing or removing these characters
# - As before, make sure your solution keeps all other aspects of the data untouched
# - Validate your solution by examining the cleaned dataset to ensure no more newline characters exist

# %%
fifa_df
# Out:
#        Unnamed: 0      ID               Name                      LongName  \
# 0               0  158023           L. Messi                  Lionel Messi
# 1               1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2               2  200389           J. Oblak                     Jan Oblak
# 3               3  192985       K. De Bruyne               Kevin De Bruyne
# 4               4  190871          Neymar Jr    Neymar da Silva Santos Jr.
# ...           ...     ...                ...                           ...
# 18974       18974  247223             Xia Ao                        Ao Xia
# 18975       18975  258760           B. Hough                     Ben Hough
# 18976       18976  252757        R. McKinley                Ronan McKinley
# 18977       18977  243790       Wang Zhen'ao                  Zhen'ao Wang
# 18978       18978  252520          Zhou Xiao                     Xiao Zhou
#
#       Nationality  Age  ↓OVA  POT                         Club     Contract  \
# 0       Argentina   33    93   93         \n\n\n\nFC Barcelona  2004 ~ 2021
# 1        Portugal   35    92   92             \n\n\n\nJuventus  2018 ~ 2022
# 2        Slovenia   27    91   93      \n\n\n\nAtlético Madrid  2014 ~ 2023
# 3         Belgium   29    91   91      \n\n\n\nManchester City  2015 ~ 2023
# 4          Brazil   28    91   91  \n\n\n\nParis Saint-Germain  2017 ~ 2022
# ...           ...  ...   ...  ...                          ...          ...
# 18974    China PR   21    47   55           \n\n\n\nWuhan Zall  2018 ~ 2022
# 18975     England   17    47   67      \n\n\n\nOldham Athletic  2020 ~ 2021
# 18976     England   18    47   65           \n\n\n\nDerry City  2019 ~ 2020
# 18977    China PR   20    47   57     \n\n\n\nDalian YiFang FC  2020 ~ 2022
# 18978    China PR   21    47   57     \n\n\n\nDalian YiFang FC  2019 ~ 2023
#
#        ...     A/W     D/W   IR PAC  SHO PAS DRI DEF PHY Hits
# 0      ...  Medium     Low  5 ★  85   92  91  95  38  65  771
# 1      ...    High     Low  5 ★  89   93  81  89  35  77  562
# 2      ...  Medium  Medium  3 ★  87   92  78  90  52  90  150
# 3      ...    High    High  4 ★  76   86  93  88  64  78  207
# 4      ...    High  Medium  5 ★  91   85  86  94  36  59  595
# ...    ...     ...     ...  ...  ..  ...  ..  ..  ..  ..  ...
# 18974  ...  Medium  Medium  1 ★  64   28  26  38  48  51  NaN
# 18975  ...  Medium  Medium  1 ★  64   40  48  49  35  45  NaN
# 18976  ...  Medium  Medium  1 ★  63   39  44  46  40  53  NaN
# 18977  ...  Medium  Medium  1 ★  58   49  41  49  30  44  NaN
# 18978  ...  Medium  Medium  1 ★  62   22  39  42  45  55  NaN
#
# [18979 rows x 35 columns]

# %%
# @title #### 02. Removing the Newline Characters

# Put your code here:
fifa_df = fifa_df.replace('\n', '', regex=True)


# ---- End of your code ----

# Submit Method
assignment_id = "00_fifa_21_players_data_analysis_and_visualization"
question_id = "02_removing_the_newline_characters"
club_col = fifa_df['Club'].head()
# club_col
# submit(student_id, name, assignment_id, club_col.to_string(), question_id, drive_link)

# %% [markdown]
# **Task 3: Removing 'Star' Characters**
#
# In this third task, we will continue with the theme of data cleaning. Your job in this task is to identify and eliminate the 'star' (★) characters from all the columns in the 'FIFA 21 Players' dataset.
#
# As guidelines for you:
# - Begin with an overview of the dataset to identify the columns that contain the 'star' ("*") characters.
# - Formulate a strategy to remove these characters without distorting the remaining data in those columns.
# - Adopt a solution that maintains the integrity of the original data.
# - Finally, validate your solution by examining the cleaned dataset, ensuring that no 'star' characters remain in any columns.

# %%
fifa_df
# Out:
#        Unnamed: 0      ID               Name                      LongName  \
# 0               0  158023           L. Messi                  Lionel Messi
# 1               1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2               2  200389           J. Oblak                     Jan Oblak
# 3               3  192985       K. De Bruyne               Kevin De Bruyne
# 4               4  190871          Neymar Jr    Neymar da Silva Santos Jr.
# ...           ...     ...                ...                           ...
# 18974       18974  247223             Xia Ao                        Ao Xia
# 18975       18975  258760           B. Hough                     Ben Hough
# 18976       18976  252757        R. McKinley                Ronan McKinley
# 18977       18977  243790       Wang Zhen'ao                  Zhen'ao Wang
# 18978       18978  252520          Zhou Xiao                     Xiao Zhou
#
#       Nationality  Age  ↓OVA  POT                 Club     Contract  ...  \
# 0       Argentina   33    93   93         FC Barcelona  2004 ~ 2021  ...
# 1        Portugal   35    92   92             Juventus  2018 ~ 2022  ...
# 2        Slovenia   27    91   93      Atlético Madrid  2014 ~ 2023  ...
# 3         Belgium   29    91   91      Manchester City  2015 ~ 2023  ...
# 4          Brazil   28    91   91  Paris Saint-Germain  2017 ~ 2022  ...
# ...           ...  ...   ...  ...                  ...          ...  ...
# 18974    China PR   21    47   55           Wuhan Zall  2018 ~ 2022  ...
# 18975     England   17    47   67      Oldham Athletic  2020 ~ 2021  ...
# 18976     England   18    47   65           Derry City  2019 ~ 2020  ...
# 18977    China PR   20    47   57     Dalian YiFang FC  2020 ~ 2022  ...
# 18978    China PR   21    47   57     Dalian YiFang FC  2019 ~ 2023  ...
#
#           A/W     D/W   IR PAC  SHO PAS DRI DEF PHY Hits
# 0      Medium     Low  5 ★  85   92  91  95  38  65  771
# 1        High     Low  5 ★  89   93  81  89  35  77  562
# 2      Medium  Medium  3 ★  87   92  78  90  52  90  150
# 3        High    High  4 ★  76   86  93  88  64  78  207
# 4        High  Medium  5 ★  91   85  86  94  36  59  595
# ...       ...     ...  ...  ..  ...  ..  ..  ..  ..  ...
# 18974  Medium  Medium  1 ★  64   28  26  38  48  51  NaN
# 18975  Medium  Medium  1 ★  64   40  48  49  35  45  NaN
# 18976  Medium  Medium  1 ★  63   39  44  46  40  53  NaN
# 18977  Medium  Medium  1 ★  58   49  41  49  30  44  NaN
# 18978  Medium  Medium  1 ★  62   22  39  42  45  55  NaN
#
# [18979 rows x 35 columns]

# %% [markdown]
# **Checking which columns contain star (★) characters**
#
# For the sake of safety, we will only remove the star characters from the columns that we want to remove. In other words, if a column contains a star character, but it is useful in some cases, we will not remove it.

# %%
fifa_df.select_dtypes(include=['object']).apply(lambda x: x.str.contains('★').sum()).sort_values(ascending=False)
# Out:
# IR                18979
# SM                18979
# W/F               18979
# Name                  0
# Loan Date End         0
# D/W                   0
# A/W                   0
# Release Clause        0
# Wage                  0
# Value                 0
# Joined                0
# LongName              0
# Best Position         0
# Preferred Foot        0
# Weight                0
# Height                0
# Positions             0
# Contract              0
# Club                  0
# Nationality           0
# Hits                  0
# dtype: int64

# %% [markdown]
# From the results above, we can conclude that column 'IR', 'SM', and 'W/F' contain star (★) characters. Because there is no additional information which columns are useful, we will remove all star (★) characters from all columns.

# %%
# @title #### 03. Removing 'Star' Characters

# Put your code here:
star_columns = ['IR', 'SM', 'W/F']
fifa_df[star_columns] = fifa_df[star_columns].replace({'★': ''}, regex=True)

# ---- End of your code ----

# Submit Method
assignment_id = "00_fifa_21_players_data_analysis_and_visualization"
question_id = "03_removing_star_characters"
star_col = fifa_df[['W/F', 'SM', 'IR']].head()
star_col
# submit(student_id, name, assignment_id, star_col.to_string(), question_id, drive_link)
# Out:
#   W/F SM  IR
# 0  4   4  5
# 1  4   5  5
# 2  3   1  3
# 3  5   4  4
# 4  5   5  5

# %%
fifa_df.select_dtypes(include=['object']).apply(lambda x: x.str.contains('★').sum()).sort_values(ascending=False)
# Out:
# Name              0
# Loan Date End     0
# IR                0
# D/W               0
# A/W               0
# SM                0
# W/F               0
# Release Clause    0
# Wage              0
# Value             0
# Joined            0
# LongName          0
# Best Position     0
# Preferred Foot    0
# Weight            0
# Height            0
# Positions         0
# Contract          0
# Club              0
# Nationality       0
# Hits              0
# dtype: int64

# %% [markdown]
# All star (★) characters have been removed from the dataset.

# %% [markdown]
# **Task 4: Filling Missing Values**
#
# In your fourth task, we turn our attention to missing values in our dataset. 'Loan End Date' and 'Hits' columns in the 'FIFA 21 Players' dataset contain some missing entries, which you are tasked with handling. Specifically, you are to fill the missing values in the 'Loan End Date' column with 'Not on Loan', and for the 'Hits' column, use the string 'Unknown'.
#
# Here are your pointers:
# - Start with identifying the missing values in the mentioned columns of 'FIFA 21 Players' dataset.
# - Apply appropriate methods to fill in the missing entries in 'Loan End Date' with 'Not on Loan' and 'Hits' column with 'Unknown', while maintaining the integrity of the existing data.
# - After filling the missing values, verify that these have been correctly filled by inspecting the final state of your DataFrame.

# %% [markdown]
# **Checking which columns contain missing values**

# %%
fifa_df.isna().sum().sort_values(ascending=False).head()
# Out:
# Loan Date End    17966
# Hits              2595
# Name                 0
# Wage                 0
# PHY                  0
# dtype: int64

# %% [markdown]
# From the results above, we know that the 'Loan End Date' and 'Hits' columns contain missing values. We will fill the missing values in the 'Loan End Date' column with 'Not on Loan', and for the 'Hits' column, we will use the string 'Unknown'.

# %%
fifa_loan = fifa_df['Loan Date End'].fillna('Not on loan')
fifa_hits = fifa_df['Hits'].fillna('Unknown')
fifa_df['Loan Date End'] = fifa_loan
fifa_df['Hits'] = fifa_hits
fifa_df[['Loan Date End', 'Hits']].tail()
# Out:
#       Loan Date End     Hits
# 18974   Not on loan  Unknown
# 18975   Not on loan  Unknown
# 18976   Not on loan  Unknown
# 18977   Not on loan  Unknown
# 18978   Not on loan  Unknown

# %% [markdown]
# All missing values have been filled.

# %%
# @title #### 04. Filling Missing Values

# Put your code here:

# ---- End of your code ----

# Submit Method
assignment_id = "00_fifa_21_players_data_analysis_and_visualization"
question_id = "04_filling_missing_values"
missing_vals_col = fifa_df[['Loan Date End', 'Hits']].tail()
display(missing_vals_col)
# submit(student_id, name, assignment_id, missing_vals_col.to_string(), question_id, drive_link)
# Out:
#       Loan Date End     Hits
# 18974   Not on loan  Unknown
# 18975   Not on loan  Unknown
# 18976   Not on loan  Unknown
# 18977   Not on loan  Unknown
# 18978   Not on loan  Unknown

# %% [markdown]
# **Task 5: Cleaning and Converting Financial Data**
#
# In this fifth task, we will focus on improving the readability and workability of the financial data within our dataset. Here, you'll need to identify the 'Value', 'Wage', and 'Release Clause' columns in the 'FIFA 21 Players' dataset, which contain '€', 'K', and 'M' characters.
#
# Here's your course of action:
# - The first step involves eliminating the '€' character in these columns, leaving only numeric values and 'K' or 'M' characters.
# - After that, you're tasked with interpreting the 'K' and 'M' suffixes in these fields as 'x1000' and 'x1,000,000' respectively and subsequently changing the values in light of this new understanding.
# - This interpreted data should then be converted to an 'int' data type, considering that these are financial amounts.
#
# Confirmation of the successful completion of the task can be achieved by validating your dataset once the changes have been made. This task will refine not just your data cleaning capabilities, but also your proficiency in handling and comprehending numerical data.

# %% [markdown]
# **Inspecting the 'Value', 'Wage', and 'Release Clause' columns**

# %%
fifa_df[['Value', 'Wage', 'Release Clause']].head()
# Out:
#      Value   Wage Release Clause
# 0  €103.5M  €560K        €138.4M
# 1     €63M  €220K         €75.9M
# 2    €120M  €125K        €159.4M
# 3    €129M  €370K          €161M
# 4    €132M  €270K        €166.5M

# %% [markdown]
# We will remove the '€' character in these columns and convert the 'K' and 'M' suffixes in these fields as 'x1000' and 'x1,000,000' respectively. Lastly, the value will be converted to an 'int' data type.

# %%
# Remove the '€' sign
fifa_df[['Value', 'Wage', 'Release Clause']] = fifa_df[['Value', 'Wage', 'Release Clause']].replace({'€': ''}, regex=True)

# Convert K and M sign to 1000 and 1000000
fifa_df[['Value', 'Wage', 'Release Clause']] = fifa_df[['Value', 'Wage', 'Release Clause']].replace({'K': 'e+03', 'M': 'e+06'}, regex=True).astype(float).astype(int)

fifa_df[['Value', 'Wage', 'Release Clause']]
# Out:
#            Value    Wage  Release Clause
# 0      103500000  560000       138400000
# 1       63000000  220000        75900000
# 2      120000000  125000       159400000
# 3      129000000  370000       161000000
# 4      132000000  270000       166500000
# ...          ...     ...             ...
# 18974     100000    1000           70000
# 18975     130000     500          165000
# 18976     120000     500          131000
# 18977     100000    2000           88000
# 18978     100000    1000           79000
#
# [18979 rows x 3 columns]

# %%
# @title #### 05. Cleaning and Converting Financial Data

# Put your code here


# ---- End of your code ----

# Submit Method
assignment_id = "00_fifa_21_players_data_analysis_and_visualization"
question_id = "05_cleaning_converting_financial_data"
converted_col = fifa_df[['Name', 'Value', 'Wage', 'Release Clause']].head()
display(converted_col)
# submit(student_id, name, assignment_id, converted_col.to_string(), question_id, drive_link)
# Out:
#                 Name      Value    Wage  Release Clause
# 0           L. Messi  103500000  560000       138400000
# 1  Cristiano Ronaldo   63000000  220000        75900000
# 2           J. Oblak  120000000  125000       159400000
# 3       K. De Bruyne  129000000  370000       161000000
# 4          Neymar Jr  132000000  270000       166500000

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# **Task 6: Pie Chart Creation - Preferred Foot**
#
# Moving on to the realm of data visualization, your sixth task is to create a Pie Chart that displays the preferred foot ('Left' or 'Right') among the 'FIFA 21 Players'. This visualization would allow us to quickly grasp the proportion of players who prefer using one foot over the other.
#
# Here are your key steps:
# - Identify the respective count of players who prefer 'Left' and 'Right' foot from the dataset.
# - Use this data to create a Pie Chart which accurately represents these proportions.
# - Your Pie Chart should include appropriate labels and title for better readability.

# %%
fifa_df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'LongName', 'Nationality', 'Age', '↓OVA',
#        'POT', 'Club', 'Contract', 'Positions', 'Height', 'Weight',
#        'Preferred Foot', 'BOV', 'Best Position', 'Joined', 'Loan Date End',
#        'Value', 'Wage', 'Release Clause', 'Total Stats', 'Base Stats', 'W/F',
#        'SM', 'A/W', 'D/W', 'IR', 'PAC', 'SHO', 'PAS', 'DRI', 'DEF', 'PHY',
#        'Hits'],
#       dtype='object')

# %%
# @title #### 06. Pie Chart Creation - Preferred Foot

# Put your code here:
fifa_df['Preferred Foot'].value_counts().plot(kind='pie', autopct='%1.1f%%', figsize=(10, 10))
plt.title('Preferred Foot Among Players', fontsize=20)
plt.ylabel('')

plt.savefig('preferred-foot.jpg', format='jpeg') # save image
plt.show()
# ---- End of your code ----

# submit_image(student_id, '06. Pie Chart Creation - Preferred Foot', './preferred-foot.jpg')

# %% [markdown]
# **Task 7: Bar Plot Creation - Top 3 FIFA 21 Players**
#
# In your seventh task of this assignment, you are to create a bar plot displaying the top 3 FIFA 21 players according to their 'OVA' scores. This graphical representation would help us quickly identify and compare goal averages between the players who have the most influence on the field.
#
# Here's your task outline:
# - From the dataset, extract the top 3 players based on their OVA scores.
# - Now, plot this data using a bar plot with the player names on the x-axis and their respective 'OVA' scores on the y-axis.
# - Make sure your bar plot is correctly labeled with title, x and y variable details, and provides a clear indication of the players and their corresponding scores.

# %%
fifa_df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'LongName', 'Nationality', 'Age', '↓OVA',
#        'POT', 'Club', 'Contract', 'Positions', 'Height', 'Weight',
#        'Preferred Foot', 'BOV', 'Best Position', 'Joined', 'Loan Date End',
#        'Value', 'Wage', 'Release Clause', 'Total Stats', 'Base Stats', 'W/F',
#        'SM', 'A/W', 'D/W', 'IR', 'PAC', 'SHO', 'PAS', 'DRI', 'DEF', 'PHY',
#        'Hits'],
#       dtype='object')

# %%
fifa_df.rename(columns={'↓OVA': 'OVA'}, inplace=True)
fifa_df['OVA']
top3_OVA = fifa_df[['Name', 'OVA']].sort_values(by='OVA', ascending=False).head(3)
top3_OVA
# Out:
#                 Name  OVA
# 0           L. Messi   93
# 1  Cristiano Ronaldo   92
# 2           J. Oblak   91

# %%
# @title #### 07. Bar Plot Creation - Top 3 FIFA 21 Players

# Put your code here:
color=['#343f85', '#5d6cc9', '#99a2de']
ax = top3_OVA.plot(kind='bar', x='Name', y='OVA', figsize=(10, 10), rot=0, legend=False, color=color)
plt.xlabel('Player Name', labelpad=15, fontsize=15)
plt.ylabel('OVA', labelpad=15, fontsize=15)
plt.title('Top 3 Players with Highest OVA', fontsize=20, pad=15)
for i, v in enumerate(top3_OVA.OVA.values):
    plt.text(i, v, v, ha='center', fontsize=15)

plt.savefig('top-3-players.jpg', format='jpeg') # save image
plt.show()
# ---- End of your code ----

# submit_image(student_id, '07. Bar Plot Creation - Top 3 FIFA 21 Players', './top-3-players.jpg')

# %% [markdown]
# **Task 8: Bar Plot Creation - Best FIFA 21 Teams**
#
# For your eighth task, your goal is to identify and display the best top 10 FIFA teams, as determined by the sum of the 'OVA' scores of their top 100 players. This exercise provides an opportunity to transform raw data into meaningful insights, which can assist in comparing and ranking teams based on cumulative player performance.
#
# Here's your plan of action:
#
# - Start by sorting the dataset in descending order according to the OVA scores. This way, you'll have the players with the highest OVA at the top.
# - After sorting, create a subset of the top 100 players from this sorted DataFrame.
# - Now, you'll need to find out how many of these top 100 players belong to each club. To do this, count the frequency of each club's appearance within those top 100 players and retain the top 10 clubs that have the highest number of top-performing players.
# - Ensure appropriate labelling on your bar plot, including the title as 'The top 100 players based on the overall score play in 10 teams', the x-axis as 'Club', and the y-axis as 'Number of Players' for easy comprehension and interpretation of the data.

# %%
# @title #### 08. Bar Plot Creation - Best FIFA 21 Teams

# Put your code here:
top100_OVA = fifa_df.sort_values(by='OVA', ascending=False).head(100)
top10_club_OVA = top100_OVA['Club'].value_counts().head(10)
top10_club_OVA.plot(kind='bar', figsize=(10,10), rot=45, color='#343f85')
plt.title('The top 100 players based on the overall score play in 10 teams', fontsize=20, pad=15)
plt.xlabel('Club', labelpad=15, fontsize=15)
plt.ylabel('Number of Players', labelpad=15, fontsize=15)
for i, v in enumerate(top10_club_OVA.values):
    plt.text(i, v+0.1, v, ha='center', fontsize=10)

plt.savefig('best-fifa-teams.jpg', format='jpeg') # save image
plt.show()
# ---- End of your code ----

# submit_image(student_id, '08. Bar Plot Creation - Best FIFA 21 Teams', './best-fifa-teams.jpg')

# %% [markdown]
# **Task 9: Bar Plot Creation - Top 10 Most Valuable FIFA 21 Teams**
#
# In the ninth task, your focus shift towards identifying and displaying the 10 most valuable FIFA teams, determined according to the player with the highest 'Value' among their top 100 players. This gives an indication of the teams that possess high-value players and are thus crucial in the game.
#
# Here's your roadmap to complete the task:
# - Group the data by teams and identify the player with the highest 'Value' for each team among their top 100 players.
# - From this processed data, further identify the top 10 teams with the most valuable players.
# - Now create a bar plot to visualize these top 10 teams and the highest player value for each. Ensure the team names are on the x-axis and player values on the y-axis.
# - Don't forget to appropriately label the plot in terms of title, x and y axis labels, for easy understanding.

# %%
top100_OVA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 0 to 126
# Data columns (total 35 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      100 non-null    int64
#  1   ID              100 non-null    int64
#  2   Name            100 non-null    object
#  3   LongName        100 non-null    object
#  4   Nationality     100 non-null    object
#  5   Age             100 non-null    int64
#  6   OVA             100 non-null    int64
#  7   POT             100 non-null    int64
#  8   Club            100 non-null    object
#  9   Contract        100 non-null    object
#  10  Positions       100 non-null    object
#  11  Height          100 non-null    object
#  12  Weight          100 non-null    object
#  13  Preferred Foot  100 non-null    object
#  14  BOV             100 non-null    int64
#  15  Best Position   100 non-null    object
#  16  Joined          100 non-null    object
#  17  Loan Date End   100 non-null    object
#  18  Value           100 non-null    int32
#  19  Wage            100 non-null    int32
#  20  Release Clause  100 non-null    int32
#  21  Total Stats     100 non-null    int64
#  22  Base Stats      100 non-null    int64
#  23  W/F             100 non-null    object
#  24  SM              100 non-null    object
#  25  A/W             100 non-null    object
#  26  D/W             100 non-null    object
#  27  IR              100 non-null    object
#  28  PAC             100 non-null    int64
#  29  SHO             100 non-null    int64
#  30  PAS             100 non-null    int64
#  31  DRI             100 non-null    int64
#  32  DEF             100 non-null    int64
#  33  PHY             100 non-null    int64
#  34  Hits            100 non-null    object
# dtypes: int32(3), int64(14), object(18)
# memory usage: 27.0+ KB

# %%
top_perform_each_team = top100_OVA.sort_values(by='Value', ascending=False).groupby('Club').head(1).reset_index()
top10_value_player = top_perform_each_team.head(10)
top10_value_player[['Name', 'Club', 'Value']]
# Out:
#              Name                 Club      Value
# 0       K. Mbappé  Paris Saint-Germain  185500000
# 1    K. De Bruyne      Manchester City  129000000
# 2       J. Sancho    Borussia Dortmund  124000000
# 3      K. Havertz              Chelsea  121000000
# 4        M. Salah            Liverpool  120500000
# 5        J. Oblak      Atlético Madrid  120000000
# 6  R. Lewandowski    FC Bayern München  111000000
# 7   M. ter Stegen         FC Barcelona  110000000
# 8         H. Kane    Tottenham Hotspur  109000000
# 9       P. Dybala             Juventus  109000000

# %%
# convert value to millions or billions
def convert_value(value):
    if value >= 1000000000:
        return str(round(value/1000000000, 2)) + 'B'
    elif value >= 1000000:
        return str(round(value/1000000, 2)) + 'M'

value_top_team_df = pd.DataFrame(value_top_team)
value_top_team_df['Value_str'] = value_top_team_df['Value'].apply(convert_value)
value_top_team_df

# %%
# convert value to millions or billions
def convert_value(value):
    if value >= 1000000000:
        return str(round(value/1000000000, 2)) + 'B'
    elif value >= 1000000:
        return str(round(value/1000000, 2)) + 'M'

top10_value_player.loc[:, 'Value_str'] = top10_value_player.loc[:, 'Value'].apply(convert_value)
top10_value_player[['Name', 'Club', 'Value_str']]
# Out:
#              Name                 Club Value_str
# 0       K. Mbappé  Paris Saint-Germain    185.5M
# 1    K. De Bruyne      Manchester City    129.0M
# 2       J. Sancho    Borussia Dortmund    124.0M
# 3      K. Havertz              Chelsea    121.0M
# 4        M. Salah            Liverpool    120.5M
# 5        J. Oblak      Atlético Madrid    120.0M
# 6  R. Lewandowski    FC Bayern München    111.0M
# 7   M. ter Stegen         FC Barcelona    110.0M
# 8         H. Kane    Tottenham Hotspur    109.0M
# 9       P. Dybala             Juventus    109.0M

# %%
# @title #### 09. Bar Plot Creation - Top 10 Most Valuable FIFA 21 Teams

# Put your code here:
top10_value_player.plot(kind='bar', x='Club', y='Value', figsize=(10, 10), rot=45, color='#343f85', legend=False)
plt.title('Top 10 Most Valuable Players in Each Team', fontsize=20, pad=15)
plt.xlabel('Club', labelpad=15, fontsize=15)
plt.ylabel('Highest Value Player (€)', labelpad=5, fontsize=15)
plt.gca().axes.yaxis.set_ticklabels([])
for i, v in enumerate(top10_value_player.loc[:, 'Value_str'].values):
    plt.text(i, top10_value_player.loc[i, 'Value'] + 1e6, v, ha='center', fontsize=10)

plt.savefig('top-10-valuable-teams.jpg', format='jpeg') # save image
plt.show()
# ---- End of your code ----

submit_image(student_id, '09. Bar Plot Creation - Top 10 Most Valuable FIFA 21 Teams', './top-10-valuable-teams.jpg')
# Out:
# 'Assignment successfully submitted'

# %% [markdown]
# **Task 10: Scatter Plot Creation - High Value, Underpaid Players**
#
# In the tenth and final task of this assignment, your challenge is to create a scatter plot to visualize high value but low paid players. This visualization will help us understand the difference that exists between player values and wages and identify any outliers in the 'Value' and 'Wage' columns.
#
# Here's your guide to tackle this task:
# - Identify the players who have high 'Value' but relatively low 'Wage' in the 'FIFA 21 Players' dataset.
# - Use this filtered data to create a scatter plot, where one axis represents the 'Value' and the other represents the 'Wage' of these players.
# - Remember to correctly label your scatter plot including an appropriate title, x and y axis details, for an accurate understanding of what your plot represents.

# %% [markdown]
# **Identifying the players who have high 'Value' but relatively low 'Wage'**
#
# We will define that players who have high 'Value' are players with 'Value' more than in the 75th percentile. While players who have relatively low 'Wage' are players with 'Wage' less than in the 25th percentile.

# %%
wage_q1 = fifa_df['Wage'].quantile(0.25)
value_q3 = fifa_df['Value'].quantile(0.75)
fifa_high_val_low_wage = fifa_df[(fifa_df['Wage'] < wage_q1) & (fifa_df['Value'] > value_q3)]

# Player example
fifa_high_val_low_wage[['Name', 'Club', 'Wage', 'Value']].head(10)
# Out:
#               Name                    Club  Wage     Value
# 372   D. Livaković           Dinamo Zagreb   900  24500000
# 697       O. Kolář         SK Slavia Praha   850  16500000
# 863    Y. El Arabi          Olympiacos CFP   500   6500000
# 1195      A. Ademi           Dinamo Zagreb   900   6500000
# 1354  V. Mykolenko             Dynamo Kyiv   700  16000000
# 1460      M. Oršić           Dinamo Zagreb   950   8000000
# 1487   T. Kędziora             Dynamo Kyiv   950   9000000
# 1509  S. Sydorchuk             Dynamo Kyiv   950   4800000
# 1545      D. Boyko             Dynamo Kyiv   750   2800000
# 1610  S. Fernández  Nacional de Montevideo   950   2300000

# %% [markdown]
# **Creating a scatter plot from the filtered data**

# %%
# @title #### 10. Scatter Plot Creation - High Value, Underpaid Players

# Put your code here:
plt.style.use('seaborn')

fifa_high_val_low_wage.plot(kind='scatter', x='Wage', y='Value', figsize=(15, 15), color='#343f85', s=75, alpha=0.75)
plt.xlabel('Wage (€)', labelpad=15, fontsize=20)
plt.ylabel('Value in M (€)', labelpad=15, fontsize=20)
plt.title('High Value Low Wage Players', fontsize=20, pad=15)

plt.savefig('high-value-underpaid-players.jpg', format='jpeg') # save image
plt.show()
# ---- End of your code ----

submit_image(student_id, '10. Scatter Plot Creation - High Value, Underpaid Players', './high-value-underpaid-players.jpg')
# Out:
# C:\Users\Byrocuy\AppData\Local\Temp/ipykernel_2644/254198559.py:4: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')
# 'Assignment successfully submitted'
